# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
tips = pd.read_csv('data/train.csv')

# %%
Sex_counts = tips['Sex'].value_counts()
#converting the counts into a DataFrame for plotting
print(Sex_counts)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
Sex_counts_df = Sex_counts.reset_index(
print(Sex_counts_df)
# Out:
#       Sex  count
# 0    male    577
# 1  female    314

# %%
Sex_counts_df.columns = ['Sex', 'Count']
#Set the seaborn theme
sns.set_theme(style="whitegrid")

#Create the barplot
sns.barplot(x='Sex', y='Count', data=Sex_counts_df)

#Add labels
plt.title('Counts of Males and Females', fontweight = 'bold')
plt.xlabel('Sex')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
SurvivedNumber = tips['Survived'].value_counts()
print(SurvivedNumber)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="Survived", y="Age", data=tips)
plt.show()

# %%
Survived_counts = tips.groupby(['Sex', 'Survived']).size().unstack()
#Set the seaborn theme
sns.set_theme(style="whitegrid")
#Create the barplot
Survived_counts.plot(kind='bar', stacked=True)
#Add title and labels
plt.title('Survivors Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'], loc="upper right")
