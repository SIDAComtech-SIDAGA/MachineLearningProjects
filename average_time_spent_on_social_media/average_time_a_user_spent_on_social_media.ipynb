# %% [markdown]
# # I am going to create dummy data for practise only
# #The description of each column is as follows

# %%
# 1.age
# 2.gender
# 3.demographics
# 4.interest: This is like like hobby
# 5.device type
# 6.location: This is the location country wide
# 7.platform: the social media platform where a user spend time
# 8.profession: a user profession status/occupants
# 9.income:yeary income of a user
# 10.indebt:indicate whether a user has a debp or nor(true or false)
# 11.homeowner:indicate wheather a user own a home or not
# 12.owns_cars:Indicate a user wheather owns a car or not(true or false)

# %%
# import necessary libraries for data analysis 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import plotly.offline as pyo
# warnings.filterwarnings('ignore')

# %%
#data creation 
num_rows = 500
data = {
    'age':np.random.randint(14,65,num_rows),
    'gender':np.random.choice(['Male','Female','non-binary'],num_rows),
    'demographic':np.random.choice(['urban', 'suburban','rural'],num_rows),
    'interest':np.random.choice(['Technology', 'Sports', 'Fashion', 'Travel','Porn'], num_rows),
    'device_type':np.random.choice(['Mobile','Desktop','Table'], num_rows),
    'device_brand': np.random.choice(['GooglePexel','Iphone','Tecno','Samsung','Itel','Microsoft','Vivo', 'Apple'], num_rows),
    'location':np.random.choice(['UK','Tanzania','US','Canada'], num_rows),
    'platform': np.random.choice(['Facebook', 'Instagram', 'Twitter', 'LinkedIn'], num_rows),
    'profession': np.random.choice(['Student', 'Engineer', 'Doctor', 'Teacher', 'Manager'], num_rows), 
    'time-spent': np.random.randint(1,60, num_rows),
    'income': np.random.randint(20000, 150000, num_rows),  
    'indebt': np.random.choice([True, False], num_rows), 
    'homeowner': np.random.choice([True, False], num_rows), 
    'owns_cars': np.random.choice([True, False], num_rows)  
   
}
file_path = 'data/data.csv'
df = pd.DataFrame(data)
df.to_csv(file_path, index=False)
print("CSV file is saved successfuly at:", file_path)
# Out:
# CSV file is saved successfuly at: data/data.csv

# %%
data2 = pd.read_csv('data/data.csv')
data2.head()
# Out:
#    age      gender demographic    interest device_type device_brand  location  \
# 0   33      Female       rural     Fashion     Desktop      Samsung  Tanzania
# 1   30      Female       urban      Sports      Mobile         Vivo    Canada
# 2   21      Female       urban  Technology     Desktop         Vivo    Canada
# 3   29        Male       rural     Fashion      Mobile        Apple    Canada
# 4   60  non-binary       urban      Sports      Mobile      Samsung        UK
#
#     platform profession  time-spent  income  indebt  homeowner  owns_cars
# 0    Twitter    Manager          31   60460   False      False       True
# 1  Instagram     Doctor           1  141684   False      False      False
# 2    Twitter    Manager          37   86097   False       True       True
# 3    Twitter    Teacher           8  104333   False      False      False
# 4   Facebook    Teacher          42  121828    True      False       True

# %%
#I GO DO THE DATA PREPROCESSING 
# 1. CHECKING THE DATA SHAPE
# 2. CHECKING THE NULL VALUES
# 3. SOME STATISTICAL INFORMATION
# 4. INFORMATION ABOUT THE DATA

# %%
def checking_data_information(data_frame):
    shape = data_frame.shape
    print('*' * 80)
    
    # Calculate null values
    null_values_info = data_frame.isna().sum() / len(data_frame)
    print(null_values_info)
    print('$' * 80)
    
    # Print DataFrame information
    print(data_frame.info())
    print('&' * 80)
    
    # Calculate and print the number of duplicated values
    duplicated_value = data_frame.duplicated().sum()  # Corrected from data.duplicate() to data_frame.duplicated()
    print(f'The dataset contains {duplicated_value} duplicated values')
    
    return shape, null_values_info, data_frame.info()

# Assuming 'data2' is your DataFrame
print(checking_data_information(data2))
# Out:
# ********************************************************************************
# age             0.0
# gender          0.0
# demographic     0.0
# interest        0.0
# device_type     0.0
# device_brand    0.0
# location        0.0
# platform        0.0
# profession      0.0
# time-spent      0.0
# income          0.0
# indebt          0.0
# homeowner       0.0
# owns_cars       0.0
# dtype: float64
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           500 non-null    int64
#  1   gender        500 non-null    object
#  2   demographic   500 non-null    object
#  3   interest      500 non-null    object
#  4   device_type   500 non-null    object
#  5   device_brand  500 non-null    object
#  6   location      500 non-null    object
#  7   platform      500 non-null    object
#  8   profession    500 non-null    object
#  9   time-spent    500 non-null    int64
#  10  income        500 non-null    int64
#  11  indebt        500 non-null    bool
#  12  homeowner     500 non-null    bool
#  13  owns_cars     500 non-null    bool
# dtypes: bool(3), int64(3), object(8)
# memory usage: 44.6+ KB
# None
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# The dataset contains 0 duplicated values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           500 non-null    int64
#  1   gender        500 non-null    object
#  2   demographic   500 non-null    object
#  3   interest      500 non-null    object
#  4   device_type   500 non-null    object
#  5   device_brand  500 non-null    object
#  6   location      500 non-null    object
#  7   platform      500 non-null    object
#  8   profession    500 non-null    object
#  9   time-spent    500 non-null    int64
#  10  income        500 non-null    int64
#  11  indebt        500 non-null    bool
#  12  homeowner     500 non-null    bool
#  13  owns_cars     500 non-null    bool
# dtypes: bool(3), int64(3), object(8)
# memory usage: 44.6+ KB
# ((500, 14), age             0.0
# gender          0.0
# demographic     0.0
# interest        0.0
# device_type     0.0
# device_brand    0.0
# location        0.0
# platform        0.0
# profession      0.0
# time-spent      0.0
# income          0.0
# indebt          0.0
# homeowner       0.0
# owns_cars       0.0
# dtype: float64, None)

# %%
#some statistical information about the data
data2.describe().style.background_gradient(cmap='RdGy_r')
# Out:
# <style type="text/css">
# #T_2cadd_row0_col0, #T_2cadd_row0_col1, #T_2cadd_row7_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_2cadd_row0_col2, #T_2cadd_row2_col0, #T_2cadd_row3_col0, #T_2cadd_row3_col1 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_2cadd_row1_col0, #T_2cadd_row5_col0 {
#   background-color: #343434;
#   color: #f1f1f1;
# }
# #T_2cadd_row1_col1, #T_2cadd_row5_col1 {
#   background-color: #363636;
#   color: #f1f1f1;
# }
# #T_2cadd_row1_col2 {
#   background-color: #feece1;
#   color: #000000;
# }
# #T_2cadd_row2_col1 {
#   background-color: #2a2a2a;
#   color: #f1f1f1;
# }
# #T_2cadd_row2_col2 {
#   background-color: #9b9b9b;
#   color: #f1f1f1;
# }
# #T_2cadd_row3_col2 {
#   background-color: #5e5e5e;
#   color: #f1f1f1;
# }
# #T_2cadd_row4_col0 {
#   background-color: #282828;
#   color: #f1f1f1;
# }
# #T_2cadd_row4_col1 {
#   background-color: #262626;
#   color: #f1f1f1;
# }
# #T_2cadd_row4_col2 {
#   background-color: #cacaca;
#   color: #000000;
# }
# #T_2cadd_row5_col2 {
#   background-color: #fef3ec;
#   color: #000000;
# }
# #T_2cadd_row6_col0 {
#   background-color: #424242;
#   color: #f1f1f1;
# }
# #T_2cadd_row6_col1 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# #T_2cadd_row6_col2 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_2cadd_row7_col0 {
#   background-color: #4e4e4e;
#   color: #f1f1f1;
# }
# #T_2cadd_row7_col1 {
#   background-color: #555555;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cadd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cadd_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_2cadd_level0_col1" class="col_heading level0 col1" >time-spent</th>
#       <th id="T_2cadd_level0_col2" class="col_heading level0 col2" >income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cadd_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_2cadd_row0_col0" class="data row0 col0" >500.000000</td>
#       <td id="T_2cadd_row0_col1" class="data row0 col1" >500.000000</td>
#       <td id="T_2cadd_row0_col2" class="data row0 col2" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_2cadd_row1_col0" class="data row1 col0" >39.966000</td>
#       <td id="T_2cadd_row1_col1" class="data row1 col1" >29.506000</td>
#       <td id="T_2cadd_row1_col2" class="data row1 col2" >83067.158000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_2cadd_row2_col0" class="data row2 col0" >14.677865</td>
#       <td id="T_2cadd_row2_col1" class="data row2 col1" >17.142394</td>
#       <td id="T_2cadd_row2_col2" class="data row2 col2" >36308.182662</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_2cadd_row3_col0" class="data row3 col0" >14.000000</td>
#       <td id="T_2cadd_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_2cadd_row3_col2" class="data row3 col2" >20127.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_2cadd_row4_col0" class="data row4 col0" >28.000000</td>
#       <td id="T_2cadd_row4_col1" class="data row4 col1" >14.000000</td>
#       <td id="T_2cadd_row4_col2" class="data row4 col2" >51485.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_2cadd_row5_col0" class="data row5 col0" >40.000000</td>
#       <td id="T_2cadd_row5_col1" class="data row5 col1" >29.500000</td>
#       <td id="T_2cadd_row5_col2" class="data row5 col2" >80352.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_2cadd_row6_col0" class="data row6 col0" >53.000000</td>
#       <td id="T_2cadd_row6_col1" class="data row6 col1" >43.000000</td>
#       <td id="T_2cadd_row6_col2" class="data row6 col2" >115031.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_2cadd_row7_col0" class="data row7 col0" >64.000000</td>
#       <td id="T_2cadd_row7_col1" class="data row7 col1" >59.000000</td>
#       <td id="T_2cadd_row7_col2" class="data row7 col2" >149879.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#EXPLORE Data Analysis Process
#QUESTIONS IS ASKED TO THE DATA. We ask questions towards the data in order to identify some intereating patters from the data
# 1. Visualize the age distribution using the a distplot
# 2. Create a pie chart to understand the gender percentages in the area
# 3. Visualize the unique plots in different locations
# 4. Visualize how many times the students use different social media platforms in different locations
# 5. Create a dataframe to visualize how many a certain profession spent time on social media
# 6. Create a dataframe for demographics, platforms, and professions

# %%
data2.head(1)
# Out:
#    age  gender demographic interest device_type device_brand  location  \
# 0   33  Female       rural  Fashion     Desktop      Samsung  Tanzania
#
#   platform profession  time-spent  income  indebt  homeowner  owns_cars
# 0  Twitter    Manager          31   60460   False      False       True

# %%
#Age distribution visualization
plt.figure(figsize=(10,6))
sns.distplot(data['age'], hist=True, kde=True)
plt.title("Age Distribution Table")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Sidaga Waziri\AppData\Local\Temp\ipykernel_9288\3676348229.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# Let's Visualize the Gender Percentage in the data
data2['gender'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',figsize=(8,6),
     explode=[0,0,0.1],
    labels=['Male','Non-binary','Female'],
    colors=['#780000','#03045e','#e7c6ff'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Visualize the Gender percentage in the data")
plt.show()

# %%
data2['location'].value_counts()
# Out:
# location
# US          135
# UK          127
# Tanzania    122
# Canada      116
# Name: count, dtype: int64

# %%
#lets find how many location in the data
data2['location'].value_counts().sort_values(ascending=False)\
.plot(kind='bar',figsize=(8,6), color=['red','blue','black','aqua'])
plt.title("Findi the how many location in the data")
plt.xlabel('Locations')
plt.ylabel('Count of the values')
plt.show()

# %%
student_data=data2[data2['profession']=='Student']
location_platform_data_frame=pd.DataFrame(student_data.groupby('location',)['platform'].value_counts().sort_values(ascending=False).unstack())
# Reshaping the DataFrame for seaborn barplot
platform_counts = location_platform_data_frame.reset_index().melt(id_vars='location', var_name='platform', value_name='count')
# Plotting with seaborn
plt.figure(figsize=(8, 6))
sns.barplot(data=platform_counts, x='location', y='count', hue='platform', palette='YlGn')
# Adding labels and title
plt.xlabel('Location')
plt.ylabel('Number of Students')
plt.title('Platform Usage by Students per Location')

# Display the plot
plt.legend(title='Platform')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
profession_platform=pd.DataFrame(data2.groupby('profession')['platform'].value_counts().sort_values(ascending=False).unstack())
profession_time=pd.DataFrame(data2.groupby('profession')['time-spent'].mean())
all_information=pd.merge(profession_platform,profession_time,on='profession')
all_information.style.background_gradient(cmap='ocean')
# Out:
# <style type="text/css">
# #T_b15aa_row0_col0, #T_b15aa_row3_col0 {
#   background-color: #001060;
#   color: #f1f1f1;
# }
# #T_b15aa_row0_col1, #T_b15aa_row1_col0, #T_b15aa_row1_col2, #T_b15aa_row2_col4, #T_b15aa_row4_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b15aa_row0_col2 {
#   background-color: #158ab1;
#   color: #f1f1f1;
# }
# #T_b15aa_row0_col3 {
#   background-color: #1b8db3;
#   color: #f1f1f1;
# }
# #T_b15aa_row0_col4 {
#   background-color: #000e4c;
#   color: #f1f1f1;
# }
# #T_b15aa_row1_col1 {
#   background-color: #000055;
#   color: #f1f1f1;
# }
# #T_b15aa_row1_col3, #T_b15aa_row2_col0, #T_b15aa_row4_col1, #T_b15aa_row4_col2, #T_b15aa_row4_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_b15aa_row1_col4 {
#   background-color: #9fcfdf;
#   color: #000000;
# }
# #T_b15aa_row2_col1 {
#   background-color: #002040;
#   color: #f1f1f1;
# }
# #T_b15aa_row2_col2 {
#   background-color: #00273b;
#   color: #f1f1f1;
# }
# #T_b15aa_row2_col3 {
#   background-color: #004080;
#   color: #f1f1f1;
# }
# #T_b15aa_row3_col1 {
#   background-color: #006095;
#   color: #f1f1f1;
# }
# #T_b15aa_row3_col2 {
#   background-color: #003176;
#   color: #f1f1f1;
# }
# #T_b15aa_row3_col3 {
#   background-color: #006699;
#   color: #f1f1f1;
# }
# #T_b15aa_row3_col4 {
#   background-color: #001362;
#   color: #f1f1f1;
# }
# #T_b15aa_row4_col0 {
#   background-color: #42a0c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b15aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b15aa_level0_col0" class="col_heading level0 col0" >Facebook</th>
#       <th id="T_b15aa_level0_col1" class="col_heading level0 col1" >Instagram</th>
#       <th id="T_b15aa_level0_col2" class="col_heading level0 col2" >LinkedIn</th>
#       <th id="T_b15aa_level0_col3" class="col_heading level0 col3" >Twitter</th>
#       <th id="T_b15aa_level0_col4" class="col_heading level0 col4" >time-spent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >profession</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b15aa_level0_row0" class="row_heading level0 row0" >Doctor</th>
#       <td id="T_b15aa_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_b15aa_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_b15aa_row0_col2" class="data row0 col2" >29</td>
#       <td id="T_b15aa_row0_col3" class="data row0 col3" >26</td>
#       <td id="T_b15aa_row0_col4" class="data row0 col4" >28.936364</td>
#     </tr>
#     <tr>
#       <th id="T_b15aa_level0_row1" class="row_heading level0 row1" >Engineer</th>
#       <td id="T_b15aa_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_b15aa_row1_col1" class="data row1 col1" >24</td>
#       <td id="T_b15aa_row1_col2" class="data row1 col2" >33</td>
#       <td id="T_b15aa_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_b15aa_row1_col4" class="data row1 col4" >30.528846</td>
#     </tr>
#     <tr>
#       <th id="T_b15aa_level0_row2" class="row_heading level0 row2" >Manager</th>
#       <td id="T_b15aa_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_b15aa_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_b15aa_row2_col2" class="data row2 col2" >23</td>
#       <td id="T_b15aa_row2_col3" class="data row2 col3" >24</td>
#       <td id="T_b15aa_row2_col4" class="data row2 col4" >30.877778</td>
#     </tr>
#     <tr>
#       <th id="T_b15aa_level0_row3" class="row_heading level0 row3" >Student</th>
#       <td id="T_b15aa_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_b15aa_row3_col1" class="data row3 col1" >27</td>
#       <td id="T_b15aa_row3_col2" class="data row3 col2" >26</td>
#       <td id="T_b15aa_row3_col3" class="data row3 col3" >25</td>
#       <td id="T_b15aa_row3_col4" class="data row3 col4" >29.168317</td>
#     </tr>
#     <tr>
#       <th id="T_b15aa_level0_row4" class="row_heading level0 row4" >Teacher</th>
#       <td id="T_b15aa_row4_col0" class="data row4 col0" >26</td>
#       <td id="T_b15aa_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_b15aa_row4_col2" class="data row4 col2" >20</td>
#       <td id="T_b15aa_row4_col3" class="data row4 col3" >29</td>
#       <td id="T_b15aa_row4_col4" class="data row4 col4" >28.105263</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouping_data=pd.DataFrame(data2.groupby(['platform','demographic'])['profession'].value_counts().sort_values().unstack())
grouping_data.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_95df5_row0_col0, #T_95df5_row4_col0, #T_95df5_row7_col0, #T_95df5_row11_col4 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_95df5_row0_col1, #T_95df5_row1_col0, #T_95df5_row3_col2, #T_95df5_row3_col4, #T_95df5_row8_col3, #T_95df5_row8_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_95df5_row0_col2, #T_95df5_row1_col2, #T_95df5_row5_col2, #T_95df5_row7_col2 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_95df5_row0_col3, #T_95df5_row5_col3, #T_95df5_row6_col3 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_95df5_row0_col4, #T_95df5_row2_col1, #T_95df5_row3_col0, #T_95df5_row4_col2, #T_95df5_row7_col3, #T_95df5_row8_col0, #T_95df5_row8_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_95df5_row1_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_95df5_row1_col3, #T_95df5_row2_col3, #T_95df5_row10_col3, #T_95df5_row11_col3 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_95df5_row1_col4, #T_95df5_row7_col4 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_95df5_row2_col0, #T_95df5_row5_col0, #T_95df5_row6_col4, #T_95df5_row9_col0 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_95df5_row2_col2, #T_95df5_row8_col2 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_95df5_row2_col4, #T_95df5_row6_col0 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_95df5_row3_col1, #T_95df5_row3_col3, #T_95df5_row6_col1, #T_95df5_row9_col3 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_95df5_row4_col1, #T_95df5_row9_col1, #T_95df5_row10_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_95df5_row4_col3 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_95df5_row4_col4, #T_95df5_row5_col4, #T_95df5_row9_col4, #T_95df5_row10_col0, #T_95df5_row11_col0 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_95df5_row5_col1, #T_95df5_row7_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_95df5_row6_col2, #T_95df5_row9_col2, #T_95df5_row10_col2 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_95df5_row10_col4 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_95df5_row11_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_95df5_row11_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# </style>
# <table id="T_95df5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >profession</th>
#       <th id="T_95df5_level0_col0" class="col_heading level0 col0" >Doctor</th>
#       <th id="T_95df5_level0_col1" class="col_heading level0 col1" >Engineer</th>
#       <th id="T_95df5_level0_col2" class="col_heading level0 col2" >Manager</th>
#       <th id="T_95df5_level0_col3" class="col_heading level0 col3" >Student</th>
#       <th id="T_95df5_level0_col4" class="col_heading level0 col4" >Teacher</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="index_name level1" >demographic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95df5_level0_row0" class="row_heading level0 row0" rowspan="3">Facebook</th>
#       <th id="T_95df5_level1_row0" class="row_heading level1 row0" >rural</th>
#       <td id="T_95df5_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_95df5_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_95df5_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_95df5_row0_col3" class="data row0 col3" >7</td>
#       <td id="T_95df5_row0_col4" class="data row0 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row1" class="row_heading level1 row1" >suburban</th>
#       <td id="T_95df5_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_95df5_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_95df5_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_95df5_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_95df5_row1_col4" class="data row1 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row2" class="row_heading level1 row2" >urban</th>
#       <td id="T_95df5_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_95df5_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_95df5_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_95df5_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_95df5_row2_col4" class="data row2 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level0_row3" class="row_heading level0 row3" rowspan="3">Instagram</th>
#       <th id="T_95df5_level1_row3" class="row_heading level1 row3" >rural</th>
#       <td id="T_95df5_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_95df5_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_95df5_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_95df5_row3_col3" class="data row3 col3" >9</td>
#       <td id="T_95df5_row3_col4" class="data row3 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row4" class="row_heading level1 row4" >suburban</th>
#       <td id="T_95df5_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_95df5_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_95df5_row4_col2" class="data row4 col2" >13</td>
#       <td id="T_95df5_row4_col3" class="data row4 col3" >11</td>
#       <td id="T_95df5_row4_col4" class="data row4 col4" >8</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row5" class="row_heading level1 row5" >urban</th>
#       <td id="T_95df5_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_95df5_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_95df5_row5_col2" class="data row5 col2" >7</td>
#       <td id="T_95df5_row5_col3" class="data row5 col3" >7</td>
#       <td id="T_95df5_row5_col4" class="data row5 col4" >8</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level0_row6" class="row_heading level0 row6" rowspan="3">LinkedIn</th>
#       <th id="T_95df5_level1_row6" class="row_heading level1 row6" >rural</th>
#       <td id="T_95df5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_95df5_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_95df5_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_95df5_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_95df5_row6_col4" class="data row6 col4" >10</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row7" class="row_heading level1 row7" >suburban</th>
#       <td id="T_95df5_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_95df5_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_95df5_row7_col2" class="data row7 col2" >7</td>
#       <td id="T_95df5_row7_col3" class="data row7 col3" >13</td>
#       <td id="T_95df5_row7_col4" class="data row7 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row8" class="row_heading level1 row8" >urban</th>
#       <td id="T_95df5_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_95df5_row8_col1" class="data row8 col1" >16</td>
#       <td id="T_95df5_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_95df5_row8_col3" class="data row8 col3" >6</td>
#       <td id="T_95df5_row8_col4" class="data row8 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level0_row9" class="row_heading level0 row9" rowspan="3">Twitter</th>
#       <th id="T_95df5_level1_row9" class="row_heading level1 row9" >rural</th>
#       <td id="T_95df5_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_95df5_row9_col1" class="data row9 col1" >7</td>
#       <td id="T_95df5_row9_col2" class="data row9 col2" >10</td>
#       <td id="T_95df5_row9_col3" class="data row9 col3" >9</td>
#       <td id="T_95df5_row9_col4" class="data row9 col4" >8</td>
#     </tr>
#     <tr>
#       <th id="T_95df5_level1_row10" class="row_heading level1 row10" >suburban</th>
#       <td id="T_95df5_row10_col0" class="data row10 col0" >8</td>
#       <td id="T_95df5_row10_col1" class="data row10 col1" >7</td>
#       <td id="T_95df5_row10_col2" class="data row10 col2
