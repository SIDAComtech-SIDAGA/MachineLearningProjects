# %% [markdown]
# # I am going to create dummy data for practise only
# #The description of each column is as follows

# %%
# 1.age
# 2.gender
# 3.demographics
# 4.interest: This is like like hobby
# 5.device type
# 6.location: This is the location country wide
# 7.platform: the social media platform where a user spend time
# 8.profession: a user profession status/occupants
# 9.income:yeary income of a user
# 10.indebt:indicate whether a user has a debp or nor(true or false)
# 11.homeowner:indicate wheather a user own a home or not
# 12.owns_cars:Indicate a user wheather owns a car or not(true or false)

# %%
# import necessary libraries for data analysis 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import plotly.offline as pyo
# warnings.filterwarnings('ignore')

# %%
#data creation 
num_rows = 500
data = {
    'age':np.random.randint(14,65,num_rows),
    'gender':np.random.choice(['Male','Female'],num_rows),
    'demographic':np.random.choice(['urban', 'suburban','rural'],num_rows),
    'interest':np.random.choice(['Technology', 'Sports', 'Fashion', 'Travel','Porn'], num_rows),
    'device_type':np.random.choice(['Mobile','Desktop','Table'], num_rows),
    'device_brand': np.random.choice(['GooglePexel','Iphone','Tecno','Samsung','Itel','Microsoft','Vivo', 'Apple'], num_rows),
    'location':np.random.choice(['UK','Tanzania','US','Canada'], num_rows),
    'platform': np.random.choice(['Facebook', 'Instagram', 'Twitter', 'LinkedIn'], num_rows),
    'profession': np.random.choice(['Student', 'Engineer', 'Doctor', 'Teacher', 'Manager'], num_rows),  
    'income': np.random.randint(20000, 150000, num_rows),  
    'indebt': np.random.choice([True, False], num_rows), 
    'homeowner': np.random.choice([True, False], num_rows), 
    'owns_cars': np.random.choice([True, False], num_rows)  
   
}
file_path = 'data/data.csv'
df = pd.DataFrame(data)
df.to_csv(file_path, index=False)
print("CSV file is saved successfuly at:", file_path)
# Out:
# CSV file is saved successfuly at: data/data.csv

# %%
data2 = pd.read_csv('data/data.csv')
data2.head()
# Out:
#    age  gender demographic interest device_type device_brand  location  \
# 0   15    Male       urban  Fashion     Desktop        Tecno  Tanzania
# 1   17  Female       urban   Travel      Mobile       Iphone        US
# 2   24    Male       rural  Fashion       Table        Apple        US
# 3   57  Female       rural  Fashion       Table         Vivo        US
# 4   17  Female       urban  Fashion      Mobile        Apple        US
#
#     platform profession  income  indebt  homeowner  owns_cars
# 0   Facebook   Engineer   89626    True      False      False
# 1  Instagram    Student   78756   False       True       True
# 2    Twitter    Teacher   74920   False       True       True
# 3   Facebook    Student  137279   False       True      False
# 4    Twitter   Engineer  126856   False      False       True

# %%
#I GO DO THE DATA PREPROCESSING 
# 1. CHECKING THE DATA SHAPE
# 2. CHECKING THE NULL VALUES
# 3. SOME STATISTICAL INFORMATION
# 4. INFORMATION ABOUT THE DATA

# %%
def checking_data_information(data_frame):
    shape = data_frame.shape
    print('*' * 80)
    
    # Calculate null values
    null_values_info = data_frame.isna().sum() / len(data_frame)
    print(null_values_info)
    print('$' * 80)
    
    # Print DataFrame information
    print(data_frame.info())
    print('&' * 80)
    
    # Calculate and print the number of duplicated values
    duplicated_value = data_frame.duplicated().sum()  # Corrected from data.duplicate() to data_frame.duplicated()
    print(f'The dataset contains {duplicated_value} duplicated values')
    
    return shape, null_values_info, data_frame.info()

# Assuming 'data2' is your DataFrame
print(checking_data_information(data2))
# Out:
# ********************************************************************************
# age             0.0
# gender          0.0
# demographic     0.0
# interest        0.0
# device_type     0.0
# device_brand    0.0
# location        0.0
# platform        0.0
# profession      0.0
# income          0.0
# indebt          0.0
# homeowner       0.0
# owns_cars       0.0
# dtype: float64
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           500 non-null    int64
#  1   gender        500 non-null    object
#  2   demographic   500 non-null    object
#  3   interest      500 non-null    object
#  4   device_type   500 non-null    object
#  5   device_brand  500 non-null    object
#  6   location      500 non-null    object
#  7   platform      500 non-null    object
#  8   profession    500 non-null    object
#  9   income        500 non-null    int64
#  10  indebt        500 non-null    bool
#  11  homeowner     500 non-null    bool
#  12  owns_cars     500 non-null    bool
# dtypes: bool(3), int64(2), object(8)
# memory usage: 40.7+ KB
# None
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# The dataset contains 0 duplicated values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           500 non-null    int64
#  1   gender        500 non-null    object
#  2   demographic   500 non-null    object
#  3   interest      500 non-null    object
#  4   device_type   500 non-null    object
#  5   device_brand  500 non-null    object
#  6   location      500 non-null    object
#  7   platform      500 non-null    object
#  8   profession    500 non-null    object
#  9   income        500 non-null    int64
#  10  indebt        500 non-null    bool
#  11  homeowner     500 non-null    bool
#  12  owns_cars     500 non-null    bool
# dtypes: bool(3), int64(2), object(8)
# memory usage: 40.7+ KB
# ((500, 13), age             0.0
# gender          0.0
# demographic     0.0
# interest        0.0
# device_type     0.0
# device_brand    0.0
# location        0.0
# platform        0.0
# profession      0.0
# income          0.0
# indebt          0.0
# homeowner       0.0
# owns_cars       0.0
# dtype: float64, None)

# %%
#some statistical information about the data
data2.describe().style.background_gradient(cmap='RdGy_r')
# Out:
# <style type="text/css">
# #T_311ca_row0_col0, #T_311ca_row7_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_311ca_row0_col1, #T_311ca_row2_col0, #T_311ca_row3_col0 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_311ca_row1_col0, #T_311ca_row5_col0 {
#   background-color: #343434;
#   color: #f1f1f1;
# }
# #T_311ca_row1_col1 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_311ca_row2_col1 {
#   background-color: #9b9b9b;
#   color: #f1f1f1;
# }
# #T_311ca_row3_col1 {
#   background-color: #5e5e5e;
#   color: #f1f1f1;
# }
# #T_311ca_row4_col0 {
#   background-color: #262626;
#   color: #f1f1f1;
# }
# #T_311ca_row4_col1 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_311ca_row5_col1 {
#   background-color: #fddfce;
#   color: #000000;
# }
# #T_311ca_row6_col0 {
#   background-color: #424242;
#   color: #f1f1f1;
# }
# #T_311ca_row6_col1 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_311ca_row7_col0 {
#   background-color: #4e4e4e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_311ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_311ca_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_311ca_level0_col1" class="col_heading level0 col1" >income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_311ca_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_311ca_row0_col0" class="data row0 col0" >500.000000</td>
#       <td id="T_311ca_row0_col1" class="data row0 col1" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_311ca_row1_col0" class="data row1 col0" >39.396000</td>
#       <td id="T_311ca_row1_col1" class="data row1 col1" >89269.618000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_311ca_row2_col0" class="data row2 col0" >14.842634</td>
#       <td id="T_311ca_row2_col1" class="data row2 col1" >36630.002222</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_311ca_row3_col0" class="data row3 col0" >14.000000</td>
#       <td id="T_311ca_row3_col1" class="data row3 col1" >20174.000000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_311ca_row4_col0" class="data row4 col0" >26.000000</td>
#       <td id="T_311ca_row4_col1" class="data row4 col1" >61306.750000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_311ca_row5_col0" class="data row5 col0" >40.000000</td>
#       <td id="T_311ca_row5_col1" class="data row5 col1" >88621.500000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_311ca_row6_col0" class="data row6 col0" >52.000000</td>
#       <td id="T_311ca_row6_col1" class="data row6 col1" >121176.750000</td>
#     </tr>
#     <tr>
#       <th id="T_311ca_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_311ca_row7_col0" class="data row7 col0" >64.000000</td>
#       <td id="T_311ca_row7_col1" class="data row7 col1" >149933.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#EXPLORE Data Analysis Process
#QUESTIONS IS ASKED TO THE DATA. We ask questions towards the data in order to identify some intereating patters from the data
# 1. Visualize the age distribution using the a distplot
# 2. Create a pie chart to understand the gender percentages in the area
# 3. Visualize the unique plots in different locations
# 4. Visualize how many times the students use different social media platforms in different locations
# 5. Create a dataframe to visualize how many a certain profession spent time on social media
# 6. Create a dataframe for demographics, platforms, and professions

# %%
data2.head(1)
# Out:
#    age gender demographic interest device_type device_brand  location  \
# 0   15   Male       urban  Fashion     Desktop        Tecno  Tanzania
#
#    platform profession  income  indebt  homeowner  owns_cars
# 0  Facebook   Engineer   89626    True      False      False

# %%
#Age distribution visualization
plt.figure(figsize=(10,6))
sns.distplot(data['age'], hist=True, kde=True)
plt.title("Age Distribution Table")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Sidaga Waziri\AppData\Local\Temp\ipykernel_5444\3676348229.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
