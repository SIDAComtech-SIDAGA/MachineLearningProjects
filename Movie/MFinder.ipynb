# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# mcu = pd.read_csv("./MCU_movies_Dataset.csv", encoding="latin1")
# mcu = pd.read_csv("./MCU_movies_Dataset.csv", encoding="iso-8859-1")
mcu = pd.read_csv("./MCU_movies_Dataset.csv", encoding="cp1252")
mcu.head()
# Out:
#    Id                               Title      Phase  \
# 0   1                            Iron Man  Phase One
# 1   2                 The Incredible Hulk  Phase One
# 2   3                          Iron Man 2  Phase One
# 3   4                                Thor  Phase One
# 4   5  Captain America: The First Avenger  Phase One
#
#                                Genres Release Date         Director  \
# 0           Action, Adventure, Sci-Fi   02-05-2008      Jon Favreau
# 1           Action, Adventure, Sci-Fi   13-06-2008  Louis Leterrier
# 2           Action, Adventure, Sci-Fi   07-05-2010      Jon Favreau
# 3  Action, Adventure, Fantasy, Sci-Fi   06-05-2011  Kenneth Branagh
# 4           Action, Adventure, Sci-Fi   22-07-2011     Joe Johnston
#
#                                         ScreenWriter  \
# 0  Mark Fergus & Hawk Ostby and Art Marcum & Matt...
# 1                                           Zak Penn
# 2                                     Justin Theroux
# ...

# %%
data = np.array(mcu)

# %%
num_rows, num_columns = data.shape

# %%
print(f"Total number of rows: {num_rows}")
print(f"Total number of columns: {num_columns}")
# Out:
# Total number of rows: 33
# Total number of columns: 18

# %%
print(mcu.shape)
# Out:
# (33, 18)

# %%
mcu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 33 non-null     int64
#  1   Title              33 non-null     object
#  2   Phase              33 non-null     object
#  3   Genres             33 non-null     object
#  4   Release Date       33 non-null     object
#  5   Director           33 non-null     object
#  6   ScreenWriter       33 non-null     object
#  7   Producer           33 non-null     object
#  8   Cast               33 non-null     object
#  9   Plot               33 non-null     object
#  10  Language           33 non-null     object
#  11  Filming Locations  23 non-null     object
#  12  Status             33 non-null     object
#  13  Movie Rating       33 non-null     object
#  14  Review Rating      23 non-null     float64
#  15  Movie Run Time     23 non-null     object
# ...

# %%
mcu.info
# Out:
# <bound method DataFrame.info of     Id                                        Title        Phase  \
# 0    1                                     Iron Man    Phase One
# 1    2                          The Incredible Hulk    Phase One
# 2    3                                   Iron Man 2    Phase One
# 3    4                                         Thor    Phase One
# 4    5           Captain America: The First Avenger    Phase One
# 5    6                                 The Avengers    Phase One
# 6    7                                   Iron Man 3    Phase Two
# 7    8                         Thor: The Dark World    Phase Two
# 8    9          Captain America: The Winter Soldier    Phase Two
# 9   10                      Guardians of the Galaxy    Phase Two
# 10  11                      Avengers: Age of Ultron    Phase Two
# 11  12                                      Ant-Man    Phase Two
# 12  13                   Captain America: Civil War  Phase Three
# ...

# %%
# First have look on the column __"Filming Locations"__ to select one location I will filter in the next step then.
mcu['Filming Locations'].unique()
# Out:
# array(['Palmdale Regional Airport, Palmdale, California, USA',
#        'Cherry Street Bridge, Toronto, Ontario, Canada',
#        'D.C. Stages, 1360 East 6th Street, Downtown, Los Angeles, California, USA',
#        'Galisteo, New Mexico, USA',
#        'Stanley Dock, Liverpool, Merseyside, England, UK',
#        'Pittsburgh, Pennsylvania, USA', 'Cary, North Carolina, USA',
#        'Shepperton Studios, Shepperton, Surrey, England, UK',
#        'Los Angeles, California, USA',
#        'Pinewood Atlanta Studios, 461 Sandy Creek Road, Fayetteville, Georgia, USA',
#        'Atlanta, Georgia, USA', 'New York City, New York, USA',
#        'Village Roadshow Studios, Oxenford, Queensland, Australia',
#        'Atlanta,Georgia,USA', 'Hertfordshire, England, UK', nan],
#       dtype=object)

# %%
#I want all further information connected to the address Cherry Street Bridge, Toronto, Ontario, Canada

# %%
find_address = mcu[mcu['Filming Locations'] == 'Cherry Street Bridge, Toronto, Ontario, Canada']

# %%
find_address
# Out:
#    Id                Title      Phase                     Genres Release Date  \
# 1   2  The Incredible Hulk  Phase One  Action, Adventure, Sci-Fi   13-06-2008
#
#           Director ScreenWriter                                  Producer  \
# 1  Louis Leterrier     Zak Penn  Avi Arad, Gale Anne Hurd and Kevin Feige
#
#                                                Cast  \
# 1  Edward Norton, Liv Tyler, Tim Roth, William Hurt
#
#                                                 Plot  \
# 1  Bruce Banner, a scientist on the run from the ...
#
#                        Language  \
# 1  English, Portuguese, Spanish
#
#                                 Filming Locations    Status Movie Rating  \
# 1  Cherry Street Bridge, Toronto, Ontario, Canada  Released        PG-13
#
#    Review Rating Movie Run Time       Budget   Box office
# 1            6.7        112 min  150000000.0  263427551.0

# %%
find_address2 = mcu['Filming Locations']
find_address2
# Out:
# 0     Palmdale Regional Airport, Palmdale, Californi...
# 1        Cherry Street Bridge, Toronto, Ontario, Canada
# 2     D.C. Stages, 1360 East 6th Street, Downtown, L...
# 3                             Galisteo, New Mexico, USA
# 4      Stanley Dock, Liverpool, Merseyside, England, UK
# 5                         Pittsburgh, Pennsylvania, USA
# 6                             Cary, North Carolina, USA
# 7     Shepperton Studios, Shepperton, Surrey, Englan...
# 8                          Los Angeles, California, USA
# 9     Shepperton Studios, Shepperton, Surrey, Englan...
# 10    Shepperton Studios, Shepperton, Surrey, Englan...
# 11    Pinewood Atlanta Studios, 461 Sandy Creek Road...
# 12                                Atlanta, Georgia, USA
# 13                         New York City, New York, USA
# 14                                Atlanta, Georgia, USA
# 15                                Atlanta, Georgia, USA
# 16    Village Roadshow Studios, Oxenford, Queensland...
# ...

# %%
find_address3 = mcu[mcu['Filming Locations'] == 'Stanley Dock, Liverpool, Merseyside, England, UK']

# %%
find_address3
# Out:
#    Id                               Title      Phase  \
# 4   5  Captain America: The First Avenger  Phase One
#
#                       Genres Release Date      Director  \
# 4  Action, Adventure, Sci-Fi   22-07-2011  Joe Johnston
#
#                            ScreenWriter     Producer  \
# 4  Christopher Markus & Stephen McFeely  Kevin Feige
#
#                                                 Cast  \
# 4  Chris Evans, Hugo Weaving, Samuel L. Jackson, ...
#
#                                                 Plot  \
# 4  Steve Rogers, a rejected military soldier tran...
#
#                      Language  \
# 4  English, Norwegian, French
#
#                                   Filming Locations    Status Movie Rating  \
# 4  Stanley Dock, Liverpool, Merseyside, England, UK  Released        PG-13
#
#    Review Rating Movie Run Time       Budget   Box office
# 4            6.9        124 min  140000000.0  370569774.0

# %%
find_address2
# Out:
# 0     Palmdale Regional Airport, Palmdale, Californi...
# 1        Cherry Street Bridge, Toronto, Ontario, Canada
# 2     D.C. Stages, 1360 East 6th Street, Downtown, L...
# 3                             Galisteo, New Mexico, USA
# 4      Stanley Dock, Liverpool, Merseyside, England, UK
# 5                         Pittsburgh, Pennsylvania, USA
# 6                             Cary, North Carolina, USA
# 7     Shepperton Studios, Shepperton, Surrey, Englan...
# 8                          Los Angeles, California, USA
# 9     Shepperton Studios, Shepperton, Surrey, Englan...
# 10    Shepperton Studios, Shepperton, Surrey, Englan...
# 11    Pinewood Atlanta Studios, 461 Sandy Creek Road...
# 12                                Atlanta, Georgia, USA
# 13                         New York City, New York, USA
# 14                                Atlanta, Georgia, USA
# 15                                Atlanta, Georgia, USA
# 16    Village Roadshow Studios, Oxenford, Queensland...
# ...

# %%
#Find a specific contact name

# %%
mcu[mcu["Cast"] .str.contains("Robert|Downey")]
# Out:
#     Id                                Title        Phase  \
# 0    1                             Iron Man    Phase One
# 2    3                           Iron Man 2    Phase One
# 5    6                         The Avengers    Phase One
# 6    7                           Iron Man 3    Phase Two
# 8    9  Captain America: The Winter Soldier    Phase Two
# 10  11              Avengers: Age of Ultron    Phase Two
# 12  13           Captain America: Civil War  Phase Three
# 15  16               Spider-Man: Homecoming  Phase Three
# 18  19               Avengers: Infinity War  Phase Three
# 21  22                    Avengers: Endgame  Phase Three
#
#                                  Genres Release Date               Director  \
# 0             Action, Adventure, Sci-Fi   02-05-2008            Jon Favreau
# 2             Action, Adventure, Sci-Fi   07-05-2010            Jon Favreau
# 5             Action, Adventure, Sci-Fi   04-05-2012            Joss Whedon
# ...

# %%
mcu[mcu["ScreenWriter"] == "Sidaga"]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Phase, Genres, Release Date, Director, ScreenWriter, Producer, Cast, Plot, Language, Filming Locations, Status, Movie Rating, Review Rating, Movie Run Time, Budget, Box office]
# Index: []

# %%
mcu[mcu["ScreenWriter"].str.contains("Christopher Markus")]
# Out:
#     Id                               Title        Phase  \
# 4    5  Captain America: The First Avenger    Phase One
# 6    7                          Iron Man 3    Phase Two
# 7    8                Thor: The Dark World    Phase Two
# 10  11             Avengers: Age of Ultron    Phase Two
# 17  18                       Black Panther  Phase Three
# 21  22                   Avengers: Endgame  Phase Three
#
#                         Genres Release Date               Director  \
# 4    Action, Adventure, Sci-Fi   22-07-2011           Joe Johnston
# 6    Action, Adventure, Sci-Fi   03-05-2013            Shane Black
# 7   Action, Adventure, Fantasy   08-11-2013            Alan Taylor
# 10   Action, Adventure, Sci-Fi   01-05-2015            Joss Whedon
# 17   Action, Adventure, Sci-Fi   16-02-2018           Ryan Coogler
# 21   Action, Adventure, Sci-Fi   26-04-2019  Anthony and Joe Russo
#
#                                          ScreenWriter     Producer  \
# ...

# %%
#FIND A SPECIFIC DATE OR PERIOD

# %%
print(mcu["Release Date"])
# Out:
# 0     02-05-2008
# 1     13-06-2008
# 2     07-05-2010
# 3     06-05-2011
# 4     22-07-2011
# 5     04-05-2012
# 6     03-05-2013
# 7     08-11-2013
# 8     04-04-2014
# 9     01-08-2014
# 10    01-05-2015
# 11    17-07-2015
# 12    06-05-2016
# 13    04-11-2016
# 14    05-05-2017
# 15    07-07-2017
# 16    03-11-2017
# 17    16-02-2018
# 18    27-04-2018
# 19    06-07-2018
# 20    08-03-2019
# 21    26-04-2019
# 22    02-07-2019
# 23    07-05-2021
# 24    09-07-2021
# 25    05-11-2021
# 26    17-12-2021
# 27    25-03-2022
# 28    06-05-2022
# 29    08-07-2022
# 30    11-11-2022
# 31    12-12-2022
# 32    12-12-2023
# Name: Release Date, dtype: object

# %%
# mcu["Release Date"] = pd.to_datetime(mcu["Release Date"])

# %%
find_year = mcu[(mcu["Release Date"] > '01-01-2022')]
find_year
# Out:
#     Id                                        Title        Phase  \
# 0    1                                     Iron Man    Phase One
# 1    2                          The Incredible Hulk    Phase One
# 2    3                                   Iron Man 2    Phase One
# 3    4                                         Thor    Phase One
# 4    5           Captain America: The First Avenger    Phase One
# 5    6                                 The Avengers    Phase One
# 6    7                                   Iron Man 3    Phase Two
# 7    8                         Thor: The Dark World    Phase Two
# 8    9          Captain America: The Winter Soldier    Phase Two
# 9   10                      Guardians of the Galaxy    Phase Two
# 10  11                      Avengers: Age of Ultron    Phase Two
# 11  12                                      Ant-Man    Phase Two
# 12  13                   Captain America: Civil War  Phase Three
# ...

# %%
find_period = mcu[(mcu['Release Date'] > '01-01-2022') & (mcu["Release Date"] <= '01-12-2022')]
find_period
# Out:
#     Id                    Title      Phase                             Genres  \
# 9   10  Guardians of the Galaxy  Phase Two  Action, Adventure, Comedy, Sci-Fi
# 10  11  Avengers: Age of Ultron  Phase Two          Action, Adventure, Sci-Fi
#
#    Release Date     Director  \
# 9    01-08-2014   James Gunn
# 10   01-05-2015  Joss Whedon
#
#                                          ScreenWriter     Producer  \
# 9   Edgar Wright & Joe Cornish and Adam McKay & Pa...  Kevin Feige
# 10               Christopher Markus & Stephen McFeely  Kevin Feige
#
#                                                  Cast  \
# 9   Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 10  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
#                                                  Plot         Language  \
# 9   A group of intergalactic criminals must pull t...          English
# 10  When Tony Stark and Bruce Banner try to jump-s...  English, Korean
#
# ...
